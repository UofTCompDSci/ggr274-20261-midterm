# %% [markdown]
# # GGR274 Midterm Test
#
# <mark> **Read this section before starting the test** </mark>
#
# ## Test Instructions
#
# - The test is divided into 7 questions with a total of 42 marks. The total number of marks for the test is 42. Complete all questions below.
#
# - The answers to the questions will be submitted on MarkUs using a similar workflow to the lab and homework assignments, except there are no automated tests available to you on MarkUs.
#
# - We have provided some code to help you check your programming work, but you are also welcome to add additional print statements to help you test your code.
#
# - In many questions we have given you values for some variables.  You code should continue to work even if we changed the values of these variables. In other words, we are grading your ability to use python to compute the answer, not just the answer itself.
#
# - Answers where you are asked to write Python code will be autograded and hand checked by the teaching team; written answers will be graded manually by the teaching team.
#
# ## Marking Rubric
#
#
# Section     | 0 | 1 | 2 | 3
# ------------|---|---|---|---
# python computation steps       |incorrect | significant errors | small error | runs correctly
# Describe what you did to the data (for each part) | No answer | A partial description is given that explains what the python code did to the data| A full description that uses data science terminology is given that explains what the python code did to the data and why this step is important | NA
# Conclusion (for each part) | No answer | The question is answered but no explanation is given or the explanation is irrelvant to the data analysis presented | The question is answered based on the data analysis presented, but the analysis does not fully support the explanation | The question is answered and the explanation is fully supported by the data analysis
#
#
# ## Aids Allowed and Academic Integrity
#
# - You are allowed to use any materials on Jupyter Hub and from the course website, as well as your own notes.
#
# - You may not use any electronic aids other than what is available to you on the computer.
#
# - As a student, you alone are responsible for ensuring the integrity of your work and for understanding what [constitutes an academic offense](https://www.artsci.utoronto.ca/current/academic-advising-and-support/student-academic-integrity/academic-misconduct).
#
# ## Time Allowed
#
# - The test will be available at 09:10 AM on Tuesday, February 10, and must be submitted on MarkUs by the end of the test period at 11:00 am (see Submission Instructions).
#
# - Late tests will receive a grade of zero unless you have an approved accommodation from your instructor. When in doubt, upload your submission anyway, even if there is a warning message. If you are writing with ATS, follow the time instructions given by ATS even if MarkUs differs and gives you a warning message.

# %% [markdown]
# ## Submission Instructions
#
# You will submit your work on [MarkUs](https://markus.teach.cs.toronto.edu/markus/main/login_remote_auth).
# To submit your work:
#
# 1. Download this file (`Midterm.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the **midterm** assignment. (See [our MarkUs Guide](../../guides/markus_guide.ipynb) for detailed instructions.)
# 3. IMPORTANT: Double-check to sure that the file is named exactly Midterm.ipynb

# %% [markdown]
# ## Question 1
#
# In the 2021 census, Ontario had a population of 14,223,942.  The City of Toronto had a population of 2,794,356. These values are represented in the variables below.

# %%
# These variables are given to you. Do not change them!
ontario_population = 14223942
toronto_population = 2794356

# %% [markdown]
# ### Question 1a (1 mark)
#
# Use `ontario_population` and `toronto_population` to calculate the *fraction* of people who live in Toronto. Store the result in a variable called `toronto_share`.

# %%
# Write your code here

# check your work
toronto_share

# %% [markdown]
# ### Question 1b  (2 marks)
#
# Step 1: Multiply `toronto_share` by 100 *and* use the Python function `round` to limit the value to two decimal places. Save the result of this as `toronto_percentage_rounded`. __(1 mark)__
#
# Step 2: Save the following sentence to `toronto_percentage_sentence`: "The percentage of Ontario residents in Toronto is \__.__%", filling in the blanks with the value of `toronto_percentage_rounded`. __(1 mark)__

# %%
# Write your code here
toronto_percentage_rounded = round(toronto_share*100, 2)



# check your work
toronto_percentage_sentence

# %% [markdown]
# ## Question 2
#
# ### Question 2a (4 marks)
#
# We have given you a long string in the code cell below.
# You have the following tasks:
#
# 1. First, **split** the string into words using the `split()` method with a correct argument. Store the result in a variable called `all_words`. __(1 mark)__
#
# 2. Create an empty list called `longer_words`. Then, using a `for` loop, iterate over `all_words`. Add words with a length greater than 3 to the list `longer_words`.  (__2 marks__).
#
# 3. Calculate the average length of the words in `longer_words`, and store it in a variable named `avg_length`. __(1 mark)__.
#
# You can print out your three variables `all_words`, `longer_words` and `avg_length` to check your work for this question.
# Remember you can also print out variables from inside the loop if you want to check intermediary steps.

# %%
# This variable is given to you: do not change it!
article = "The Black History Month Luncheon will host a celebrated Toronto TV personality, a spoken word poet and human rights activist - and two women who, as high school students, found a new way to solve a math problem that's thousands of years old."

# Write your code here

# %% [markdown]
# ### Question 2b (2 marks)
#
# Given the list below, remove all punctuation in this string by replacing periods, commas, hypens, and apostrophes (single quotes) with a blank character. (This step was **not** part of Question 2a.)

# %%
# This variable is given to you. Your code should work even if we change the value of the variable.
sentence = "Adding to the celebration, Matthew-Ray 'Testament' Jones, Ontario's Poet Laureate, will share original spoken-word poetry." 

# Write your code here

# %% [markdown]
# ## Question 3
#
# The following list contains the population of each province/territory in 2024:

# %%
# This variable is given to you. Do not change it!
# Your solutions to this problem should still work with different populations
# or number of provinces.
province_population = [
    4957075, 
    5696852, 
    1500464, 
    863841, 
    548402, 
    45520, 
    1088273, 
    41486, 
    16228152, 
    180877, 
    9038268, 
    1256983, 
    47939
]

# %% [markdown]
# ### Question 3a  (2 marks)
#
# 1. Calculate the number of observations in `province_population` and store it as `province_num`. **(0.5 marks)**
#
# 2. Calculate the **sum** of `province_population` and store it as `province_population_sum`. **(0.5 marks)**
#
# 3. Calculate the **mean** (average) population of `province_population` and store it as `province_population_mean`. **(1 mark)**

# %%
# Write your code here

# %% [markdown]
# ### Question 3b (2 marks)
#
# Use a for loop and an if statement to count the number of provinces/territories in `province_population` with a population less than 1 million. Assign this count to a new variable named `num_small_provinces`.

# %%
# Write your code here

# %% [markdown]
# ## Question 4
#
# ### Question 4a (3 marks)
#
# The poem "Dreams" by Langston Hughes is given as a string assigned to a variable.
#
# ```python
# dreams_orig = "Hold fast to dreams / For if dreams die / Life is a broken-winged bird / That cannot fly. / Hold fast to dreams / For when dreams go / Life is a barren field / Frozen with snow."
# ```
#
# In the code cell below the poem has been "cleaned" to remove capital letters and punctuation. Your task is to create a dictionary called `poem_words` whose keys are the words in the poem, and whose values are the number of times the word appears in the poem.

# %%
dreams = "hold fast to dreams for if dreams die life is a broken winged bird that cannot fly hold fast to dreams for when dreams go life is a barren field frozen with snow"

# Write your code here

# %% [markdown]
# ### Question 4b (2 marks)
#
# Write a snippet of Python that sets the variable `one_count` to the number of words that appear only once in the poem.  Use the dictionary to compute this value.  Do not use pandas.

# %%
# Write your code here

# %% [markdown]
# ## Question 5

# %% [markdown]
# For this question, examine the following code block and respond to the questions corresponding with each line of code below.  Note that you won't be able to run this code because the file does not exist.

# %% [markdown]
# ```python
# survey_data = open("some_survey.csv", encoding="utf-8").readlines()    # Question 5a
#
# data = []      # Question 5b
#
# for line in survey_data:
#     entries = line.split(",")       # Question 5c
#
#     data_entry = entries[2].strip()     # Question 5d
#
#     data.append(data_entry)        # Question 5e
# ```

# %% [markdown]
# ### Question 5a (1 mark)
#
# What *type* of object is the `survey_data` object created in the code above? What does each item within this object represent? Answer in 1-2 sentences.

# %% [markdown]
# > Your Answer Here

# %% [markdown]
# ### Question 5b (1 mark)
#
# Why do we need to run `data = []` before running the `for` loop? In one or two sentence explain what this line does.

# %% [markdown]
# > Your Answer Here

# %% [markdown]
# ### Question 5c (2 marks)
#
# In the first line of the `for` loop, why do we use `.split(",")`? What type of object is created by this line and saved into `entries`? Answer in 2-3 sentences.

# %% [markdown]
# > Your Answer Here

# %% [markdown]
# ### Question 5d (2 marks)
#
# In the second line of the for loop, why do we include `[2]`? What type of object is created by this line and saved into `data_entry`? Answer in 2-3 sentences.

# %% [markdown]
# > Your Answer Here

# %% [markdown]
# ### Question 5e (2 marks)
#
# In the third line of the `for` loop, what does the code `data.append(data_entry)` accomplish? What is contained in `data` after this `for` loop has been completed, and what part of the original CSV file does this object represent? Answer in 2-3 sentences.

# %% [markdown]
# > Your Answer Here

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Question 6a (1 mark)
#
# Read the CSV file `ggr274_survey.csv` into a pandas `DataFrame` and store it in the variable `survey_data`.

# %%
import pandas as pd

# Write your code here

# %% [markdown]
# ### Question 6b (1 mark)
#
# Create a **list** containing the following column names from `survey_data` and store this list in a variable named `important_columns`:
#
# - "id"
#
# - "drink_type"
#
# - "cups_per_week"
#
# **Important: Make sure that the column names in `important_columns` are in the order presented above (i.e., the first element of the list should be `"id"`).**

# %%
# Write your code here

# %% [markdown]
# ### Question 6c (1 mark)
#
# Use `important_columns` to create a new `DataFrame` from `survey_data` that only contains the three columns listed in Question 6b and store this new `DataFrame` in a variable named `drink_data`.

# %%
# Write your code here

# %% [markdown]
# ### Question 6d (1 mark)
#
# Create a boolean variable that is `True` if the `drink_type` column from `drink_data` is equal to "Coffee" and `False` otherwise. Name this variable `coffee_boolean`.

# %%
# Write your code here

# %% [markdown]
# ### Question 6e (1 mark)
#
# Use the `coffee_boolean` variable from part 6d to filter (i.e. select) the rows of `drink_data` where respondents prefer coffee.  Store this filtered DataFrame as a new DataFrame called `coffee_data`.

# %%
# Write your code here

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Question 7a (1 mark)
#
# Read the CSV file `en_climate_daily_ON_6158731_2026_P1D.csv` into a pandas `DataFrame` and store it in the variable `climate`.

# %%
import pandas as pd

# Write your code here

# %% [markdown]
# ### Question 7b  (2 marks)
#
# Create new summary variables according to the following instructions:
#
# - Calculate the minimum value in the `"Total Snow (cm)"` column and assign it to `min_snowfall`. **(0.5 marks)**
#
# - Calculate the maximum value in the `"Total Snow (cm)"` column and assign it to `max_snowfall`. **(0.5 marks)**
#
# - Calculate the total sum of the `"Total Snow (cm)"` column and assign it to `total_snowfall`. **(0.5 marks)**
#
# - Calculate the mean value in the `"Total Snow (cm)"` column and assign it to `mean_snowfall`. **(0.5 marks)**

# %%
# Write your code here

# %% [markdown]
# ### Question 7c (1 mark)
#
# What *percentage*, rounded to the nearest integer, of total snowfall in January 2026 fell during a **single** day? Using the variables created in Question 6b, create a new variable called `biggest_day_percentage`.

# %%
# Write your code here

# %% [markdown]
# ### Question 7d (3 marks)
#
# For what percentage of *days* in January 2026 did Toronto have significant snowfall (1cm or greater)?
#
# - Create a boolean series named `snow_1cm` for values in `"Total Snow (cm)"` greater than or equal to 1. **(1 mark)**
#
# - Using `snow_1cm`, calculate the total number of days *with significant snowfall* and save this value as `snow_days`. **0.5 marks)**
#
# - Using `snow_1cm`, calculate the *total* number of days in the data, and save it as `total_days`. **(0.5 marks)**
#
# - Using `snow_days` and `total_days`, calculate the **percentage** of days with significant snowfall. Save this value as `snow_days_share`. **(1 mark)**

# %%
# Write your code here

# %% [markdown]
# ## Question 7e (2 marks)
#
# Comupte the median value of the `"Total Snow (cm)"` column, and store it in a variable called `median_snow`.

# %%
# Write your code here

# %% [markdown]
# ## Question 7f  (2 marks)
#
# From the computations above, we have learned that the median snowfall in January was considerably smaller than the average.  What does that tell you about the *distribution* of snowfall in January? Answer in 2-3 sentences.

# %% [markdown]
# > Your Answer Here
